# %% [markdown]
# <a href="https://colab.research.google.com/github/UditSrinivasan/dataScience_learn/blob/main/Image_to_Sketch_Project_UDIT_SRINIVASAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Converting an Image to a pencil Sketch**

# %% [markdown]
# # Adding Libraries

# %%
import cv2
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %% [markdown]
# # Loading and Plotting the orignal Image

# %%
img = cv2.imread("Udit3.jpg")
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.figure(figsize=(8,8))
plt.imshow(img)
plt.axis("off")
plt.title("Udit's Image")
plt.show()

# %% [markdown]
# # Conveerting to Gray Scale

# %%
img_gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(8,8))
plt.imshow(img_gray,cmap="gray")
plt.axis("off")
plt.title("GrayScale Image")
plt.show()

# %% [markdown]
# # Inverting The Image

# %%
img_invert = cv2.bitwise_not(img_gray)
plt.figure(figsize=(8,8))
plt.imshow(img_invert,cmap="gray")
plt.axis("off")
plt.title("Inverted Image")
plt.show()

# %% [markdown]
# # Smoothening The Image

# %%
img_smoothening =cv2.GaussianBlur(img_invert,(21,21),sigmaX=0,sigmaY=0)
plt.figure(figsize=(8,8))
plt.imshow(img_smoothening,cmap="gray")
plt.axis("off")
plt.title("Smoothen Image")
plt.show()

# %% [markdown]
# # Showing The Pencil Sketch

# %%
final = cv2.divide(img_gray, 255 - img_smoothening, scale=215)
plt.figure(figsize=(8,8))
plt.imshow(final,cmap="gray")
plt.axis("off")
plt.title("Sketched Image")
plt.show()
